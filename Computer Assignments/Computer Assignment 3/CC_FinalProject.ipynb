# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Dropout,Activation,Input,Flatten
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
import random

# %%
import pandas as pd
import numpy as np

# %%
parameters = pd.read_csv('ParametersDataset.csv')
pattern = pd.read_csv('PatternDataset.csv')

# %%
parameters
# Out:
#         Column1       Column2       Column3       Column4       Column5  \
# 0  3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# 1  1.500000e-01  1.500000e-01  1.500000e-01  1.500000e-01  1.500000e-01
# 2  3.000000e-02  3.000000e-02  3.000000e-02  3.093700e-02  3.093700e-02
# 3  2.000000e+09  2.012500e+09  2.025000e+09  2.000000e+09  2.012500e+09
#
#         Column6       Column7       Column8       Column9      Column10  ...  \
# 0  3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01  ...
# 1  1.500000e-01  1.500000e-01  1.500000e-01  1.500000e-01  1.546870e-01  ...
# 2  3.093700e-02  3.187500e-02  3.187500e-02  3.187500e-02  3.000000e-02  ...
# 3  2.025000e+09  2.000000e+09  2.012500e+09  2.025000e+09  2.000000e+09  ...
#
#     Column72.15   Column73.15   Column74.15   Column75.15   Column76.15  \
# 0  5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01  5.000000e-01
# 1  2.956250e-01  3.000000e-01  3.000000e-01  3.000000e-01  3.000000e-01
# ...

# %%
pattern
# Out:
#       Column1    Column2    Column3    Column4    Column5    Column6  \
# 0   -2.851472  -2.833037  -2.818918  -2.810664  -2.793551  -2.780483
# 1   -3.675394  -3.700862  -3.722869  -3.633762  -3.660300  -3.683143
# 2   -4.133559  -4.225237  -4.304977  -4.089050  -4.181504  -4.261840
# 3   -4.001553  -4.160083  -4.302769  -3.954363  -4.113038  -4.255730
# 4   -3.418395  -3.610925  -3.789871  -3.371578  -3.563475  -3.741626
# 5   -2.855638  -3.045657  -3.227272  -2.812821  -3.001608  -3.181787
# 6   -2.815344  -2.981247  -3.144803  -2.779561  -2.943831  -3.105525
# 7   -3.754727  -3.882525  -4.014743  -3.729380  -3.855178  -3.985188
# 8   -6.212861  -6.277389  -6.353945  -6.203676  -6.265509  -6.339253
# 9  -10.506419 -10.444755 -10.394215 -10.513453 -10.447420 -10.392573
# 10 -11.268599 -11.304992 -11.302145 -11.217389 -11.252531 -11.248435
# 11  -7.878341  -8.053199  -8.203067  -7.820728  -7.994108  -8.142525
# 12  -6.944567  -7.152592  -7.354733  -6.900922  -7.107514  -7.308152
# ...

# %%
parameters.iloc[3] = parameters.iloc[3]/1e8
X = pattern.to_numpy().T
y = parameters.to_numpy().T
y[0]
# Out:
# array([ 0.3 ,  0.15,  0.03, 20.  ])

# %%
X[0]
# Out:
# array([ -2.851472,  -3.675394,  -4.133559,  -4.001553,  -3.418395,
#         -2.855638,  -2.815344,  -3.754727,  -6.212861, -10.506419,
#        -11.268599,  -7.878341,  -6.944567,  -9.297998, -16.623355,
#        -13.681424,  -9.059088,  -9.137723, -14.332212, -23.805595,
#        -10.748482,  -7.279456,  -6.908404,  -8.945689, -14.541197,
#        -31.873764, -13.346326,  -8.174431,  -5.425264,  -3.71327 ,
#         -2.564871,  -1.780032,  -1.290364,  -1.112153,  -1.333516,
#         -2.136654,  -3.903414,  -7.651617, -17.598619,  -9.715043,
#         -2.502027,   1.126666,   2.844269,   2.990787,   1.555961,
#         -1.142109,  -1.74877 ,   1.061232,   3.280069,   4.259396,
#          4.331217,   3.865379,   3.179532,   2.47662 ,   1.816333,
#          1.171002,   0.498025,  -0.232852,  -1.040325,  -1.926889])

# %%
train_idx = np.random.randint(1296, size=1290)
test_idx = np.random.randint(1296, size=6)

X_train = X[train_idx,:]
y_train = y[train_idx,:]
X_test = X[test_idx,:]
y_test = y[test_idx,:]
X_test
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1290, 60), (1290, 4), (6, 60), (6, 4))

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(60,)))
model.add(layers.Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(layers.Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(4))
optimizer = Adam(lr=0.005)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 8ms/step - loss: 17.5651
# Epoch 2/200
# 21/21 [==============================] - 0s 7ms/step - loss: 5.7040
# Epoch 3/200
# 21/21 [==============================] - 0s 9ms/step - loss: 4.7830
# Epoch 4/200
# 21/21 [==============================] - 0s 8ms/step - loss: 4.0450
# Epoch 5/200
# 21/21 [==============================] - 0s 11ms/step - loss: 3.9064
# Epoch 6/200
# 21/21 [==============================] - 0s 12ms/step - loss: 4.0281
# Epoch 7/200
# 21/21 [==============================] - 0s 13ms/step - loss: 3.1371
# Epoch 8/200
# 21/21 [==============================] - 0s 13ms/step - loss: 2.6684
# Epoch 9/200
# 21/21 [==============================] - 0s 13ms/step - loss: 3.8338
# Epoch 10/200
# 21/21 [==============================] - 0s 12ms/step - loss: 3.8981
# Epoch 11/200
# 21/21 [==============================] - 0s 12ms/step - loss: 2.5047
# Epoch 12/200
# ...

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 116ms/step
# array([[ 0.4267951 ,  0.24109367,  0.05186379, 22.80456   ],
#        [ 0.46956602,  0.27102467,  0.05491298, 23.542824  ],
#        [ 0.33851427,  0.17129165,  0.03029491, 20.821371  ],
#        [ 0.33394715,  0.15886563,  0.03298518, 20.515186  ],
#        [ 0.33708516,  0.16705135,  0.0295681 , 20.743458  ],
#        [ 0.33793047,  0.16802919,  0.02939084, 20.752104  ]],
#       dtype=float32)

# %%
y_test
# Out:
# array([[ 0.425   ,  0.253125,  0.050625, 22.5     ],
#        [ 0.46875 ,  0.276562,  0.054375, 23.25    ],
#        [ 0.3375  ,  0.178125,  0.035625, 20.75    ],
#        [ 0.30625 ,  0.159375,  0.031875, 20.25    ],
#        [ 0.33125 ,  0.16875 ,  0.03375 , 20.75    ],
#        [ 0.325   ,  0.178125,  0.034687, 20.75    ]])
